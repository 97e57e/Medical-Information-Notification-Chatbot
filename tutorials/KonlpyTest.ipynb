# %%
from konlpy.tag import Mecab

# %%
m = Mecab()
text = "대부분 증상이 없지만 일부에서 합병증이 발생하면 그와 연관된 증상이 생길 수 있다. 예를 들어 혈액 내에 중성지방이 크게 증가하면 췌장염이 발생할 수 있으며 췌장염의 증상은 복통으로 나타날 수 있다. 일부 환자의 경우 아킬레스건에 황색종(xanthoma; 콜레스테롤이나 이와 함께 다른 지질(脂質)이 피부에 침착하여 생기는 황색의 종양)이 생길 수 있다. 눈꺼풀에 황색판종(xanthelasma; 눈꺼풀에 생기는 가장 흔한 황색종의 형태)이 나타나기도 한다. 또한 콜레스테롤이 혈관벽에 쌓여 죽상경화증을 일으키고 그 결과 협심증, 심근경색, 뇌졸중 등 심혈관계 질환을 일으킨다."

# %% [markdown]
# ## morphs(phrase)
# 형태소로 파싱

# %%
m.morphs(text)
# Out:
# ['대부분',
#  '증상',
#  '이',
#  '없',
#  '지만',
#  '일부',
#  '에서',
#  '합병증',
#  '이',
#  '발생',
#  '하',
#  '면',
#  '그',
#  '와',
#  '연관',
#  '된',
#  '증상',
#  '이',
#  '생길',
#  '수',
#  '있',
#  '다',
#  '.',
#  '예',
#  '를',
#  '들',
#  '어',
#  '혈액',
#  '내',
#  '에',
#  '중성',
#  '지방',
#  '이',
#  '크',
#  '게',
#  '증가',
#  '하',
#  '면',
#  '췌장염',
#  '이',
#  '발생',
#  '할',
#  '수',
#  '있',
#  '으며',
#  '췌장염',
#  '의',
#  '증상',
#  '은',
#  '복통',
#  '으로',
#  '나타날',
#  '수',
#  '있',
#  '다',
#  '.',
#  '일부',
#  '환자',
#  '의',
#  '경우',
#  '아킬레스건',
#  '에',
#  '황색종',
#  '(',
#  'xanthoma',
#  ';',
#  '콜레스테롤',
#  '이나',
#  '이',
#  '와',
#  '함께',
#  '다른',
#  '지질',
#  '(',
#  '脂質',
#  ')',
#  '이',
#  '피부',
#  '에',
#  '침착',
#  '하',
#  '여',
#  '생기',
#  '는',
#  '황색',
#  '의',
#  '종양',
#  ')',
#  '이',
#  '생길',
#  '수',
#  '있',
#  '다',
#  '.',
#  '눈꺼풀',
#  '에',
#  '황',
#  '색판',
#  '종',
#  '(',
#  'xanthelasma',
#  ';',
#  '눈꺼풀',
#  '에',
#  '생기',
#  '는',
#  '가장',
#  '흔한',
#  '황색종',
#  '의',
#  '형태',
#  ')',
#  '이',
#  '나타나',
#  '기',
#  '도',
#  '한다',
#  '.',
#  '또한',
#  '콜레스테롤',
#  '이',
#  '혈관',
#  '벽',
#  '에',
#  '쌓여',
#  '죽상',
#  '경화증',
#  '을',
#  '일으키',
#  '고',
#  '그',
#  '결과',
#  '협심증',
#  ',',
#  '심근',
#  '경색',
#  ',',
#  '뇌졸중',
#  '등',
#  '심혈',
#  '관계',
#  '질환',
#  '을',
#  '일으킨다',
#  '.']

# %% [markdown]
# ## nouns(phrase)
# 명사 추출

# %%
m.nouns(text)
# Out:
# ['대부분',
#  '증상',
#  '일부',
#  '합병증',
#  '발생',
#  '그',
#  '연관',
#  '증상',
#  '수',
#  '예',
#  '혈액',
#  '내',
#  '중성',
#  '지방',
#  '증가',
#  '췌장염',
#  '발생',
#  '수',
#  '췌장염',
#  '증상',
#  '복통',
#  '수',
#  '일부',
#  '환자',
#  '경우',
#  '아킬레스건',
#  '황색종',
#  '콜레스테롤',
#  '이',
#  '지질',
#  '脂質',
#  '피부',
#  '침착',
#  '황색',
#  '종양',
#  '수',
#  '눈꺼풀',
#  '황',
#  '색판',
#  '종',
#  '눈꺼풀',
#  '황색종',
#  '형태',
#  '콜레스테롤',
#  '혈관',
#  '벽',
#  '죽상',
#  '경화증',
#  '결과',
#  '협심증',
#  '심근',
#  '경색',
#  '뇌졸중',
#  '등',
#  '심혈',
#  '관계',
#  '질환']

# %% [markdown]
# ## pos(phrase, flatten=True)
# flatten – False일시 어절 보존 ( 패키지 자체 문제로 동작 안함)

# %%
m.pos(text)
# Out:
# [('대부분', 'NNG'),
#  ('증상', 'NNG'),
#  ('이', 'JKS'),
#  ('없', 'VA'),
#  ('지만', 'EC'),
#  ('일부', 'NNG'),
#  ('에서', 'JKB'),
#  ('합병증', 'NNG'),
#  ('이', 'JKS'),
#  ('발생', 'NNG'),
#  ('하', 'XSV'),
#  ('면', 'EC'),
#  ('그', 'NP'),
#  ('와', 'JKB'),
#  ('연관', 'NNG'),
#  ('된', 'XSV+ETM'),
#  ('증상', 'NNG'),
#  ('이', 'JKS'),
#  ('생길', 'VV+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('예', 'NNG'),
#  ('를', 'JKO'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  ('혈액', 'NNG'),
#  ('내', 'NNB'),
#  ('에', 'JKB'),
#  ('중성', 'NNG'),
#  ('지방', 'NNG'),
#  ('이', 'JKS'),
#  ('크', 'VA'),
#  ('게', 'EC'),
#  ('증가', 'NNG'),
#  ('하', 'XSV'),
#  ('면', 'EC'),
#  ('췌장염', 'NNG'),
#  ('이', 'JKS'),
#  ('발생', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('으며', 'EC'),
#  ('췌장염', 'NNG'),
#  ('의', 'JKG'),
#  ('증상', 'NNG'),
#  ('은', 'JX'),
#  ('복통', 'NNG'),
#  ('으로', 'JKB'),
#  ('나타날', 'VV+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('일부', 'NNG'),
#  ('환자', 'NNG'),
#  ('의', 'JKG'),
#  ('경우', 'NNG'),
#  ('아킬레스건', 'NNG'),
#  ('에', 'JKB'),
#  ('황색종', 'NNG'),
#  ('(', 'SSO'),
#  ('xanthoma', 'SL'),
#  (';', 'SY'),
#  ('콜레스테롤', 'NNG'),
#  ('이나', 'JC'),
#  ('이', 'NP'),
#  ('와', 'JKB'),
#  ('함께', 'MAG'),
#  ('다른', 'MM'),
#  ('지질', 'NNG'),
#  ('(', 'SSO'),
#  ('脂質', 'NNG'),
#  (')', 'SSC'),
#  ('이', 'JKS'),
#  ('피부', 'NNG'),
#  ('에', 'JKB'),
#  ('침착', 'NNG'),
#  ('하', 'XSA'),
#  ('여', 'EC'),
#  ('생기', 'VV'),
#  ('는', 'ETM'),
#  ('황색', 'NNG'),
#  ('의', 'JKG'),
#  ('종양', 'NNG'),
#  (')', 'SSC'),
#  ('이', 'JKS'),
#  ('생길', 'VV+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('눈꺼풀', 'NNG'),
#  ('에', 'JKB'),
#  ('황', 'NNG'),
#  ('색판', 'NNG'),
#  ('종', 'NNG'),
#  ('(', 'SSO'),
#  ('xanthelasma', 'SL'),
#  (';', 'SY'),
#  ('눈꺼풀', 'NNG'),
#  ('에', 'JKB'),
#  ('생기', 'VV'),
#  ('는', 'ETM'),
#  ('가장', 'MAG'),
#  ('흔한', 'VA+ETM'),
#  ('황색종', 'NNG'),
#  ('의', 'JKG'),
#  ('형태', 'NNG'),
#  (')', 'SSC'),
#  ('이', 'JKS'),
#  ('나타나', 'VV'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('한다', 'VV+EF'),
#  ('.', 'SF'),
#  ('또한', 'MAJ'),
#  ('콜레스테롤', 'NNG'),
#  ('이', 'JKS'),
#  ('혈관', 'NNG'),
#  ('벽', 'NNG'),
#  ('에', 'JKB'),
#  ('쌓여', 'VV+EC'),
#  ('죽상', 'NNG'),
#  ('경화증', 'NNG'),
#  ('을', 'JKO'),
#  ('일으키', 'VV'),
#  ('고', 'EC'),
#  ('그', 'MM'),
#  ('결과', 'NNG'),
#  ('협심증', 'NNG'),
#  (',', 'SC'),
#  ('심근', 'NNG'),
#  ('경색', 'NNG'),
#  (',', 'SC'),
#  ('뇌졸중', 'NNG'),
#  ('등', 'NNB'),
#  ('심혈', 'NNG'),
#  ('관계', 'NNG'),
#  ('질환', 'NNG'),
#  ('을', 'JKO'),
#  ('일으킨다', 'VV+EF'),
#  ('.', 'SF')]
